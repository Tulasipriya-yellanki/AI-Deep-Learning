# %% [markdown]
# <a href="https://colab.research.google.com/github/Tulasipriya-yellanki/AI-Deep-Learning/blob/main/activation_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

x = np.linspace(-10,10,100)
plt.figure(figsize=(10,4))
plt.plot(x, sigmoid(x), linewidth=3)
plt.title("Sigmoid Activation")
plt.grid(True, alpha=0.8)

# %%
def tanh(x):
  return np.tanh(x)

x = np.linspace(-10,10,100)
plt.figure(figsize=(10,4))
plt.plot(x, tanh(x), linewidth=3)
plt.title("Tanh Activation")
plt.grid(True, alpha=0.8)

# %%
#recitified linear unit
def relu(x):
  return np.maximum(0, x)

x = np.linspace(-10,10,100)
plt.figure(figsize=(10,4))
plt.plot(x, relu(x), linewidth=3)
plt.title("RELU Activation")
plt.grid(True, alpha=0.8)

# %%
#recitified linear unit
def leaky_relu(x, alpha=0.05):
  return np.where(x>0, x, alpha*x)

x = np.linspace(-10,10,100)
plt.figure(figsize=(10,4))
plt.plot(x, leaky_relu(x), linewidth=3)
plt.title("Leaky RELU Activation")
plt.grid(True, alpha=0.8)

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

sigmoid(13.12)
# Out:
# 0.9999979952716741
